# %%
from collections import Counter
import re
from typing import List, Set, Dict, Tuple

class EnhancedSpellingCorrector:
    def __init__(self):
        self.word_counts = Counter()
        self.misspelling_dict = {}
        self.debug_mode = True 
        
    def train_from_birkbeck(self, text: str):
        """Train from Birkbeck format ($correct\nmisspelling\nmisspelling...)"""
        current_word = None
        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue
            if line.startswith('$'):
                current_word = line[1:].lower().replace('_', ' ')
                self.word_counts[current_word] += 1
                if self.debug_mode:
                    print(f"Added correct word: {current_word}")
            elif current_word:
                misspelling = line.lower().replace('_', ' ')
                self.misspelling_dict[misspelling] = current_word
                if self.debug_mode:
                    print(f"Added misspelling: {misspelling} -> {current_word}")

    def train_from_holbrook(self, text: str):
        """Train from Holbrook tagged format."""
        err_pattern = re.compile(r'<ERR targ=([^>]+)>\s*([^<]+)\s*</ERR>')
        for match in err_pattern.finditer(text):
            correct = match.group(1).lower().replace('_', ' ')
            misspelling = match.group(2).lower().replace('_', ' ')
            if correct != '?':
                self.word_counts[correct] += 1
                self.misspelling_dict[misspelling] = correct
                if self.debug_mode:
                    print(f"Added Holbrook pair: {misspelling} -> {correct}")

    def correct(self, word: str) -> str:
        """Return the most probable spelling correction for the word."""
        word = word.lower()
        
        # If word is known, return it
        if word in self.word_counts:
            return word
            
        # If word is a known misspelling, return correction
        if word in self.misspelling_dict:
            if self.debug_mode:
                print(f"Found correction for {word}: {self.misspelling_dict[word]}")
            return self.misspelling_dict[word]
            
        # Get possible corrections (edit distance 1)
        candidates = self.get_edits(word)
        
        # Filter to known words and sort by frequency
        valid_candidates = [(w, self.word_counts[w]) for w in candidates if w in self.word_counts]
        
        if valid_candidates:
            best_candidate = max(valid_candidates, key=lambda x: x[1])[0]
            if self.debug_mode:
                print(f"Found edit distance correction for {word}: {best_candidate}")
            return best_candidate
        
        if self.debug_mode:
            print(f"No correction found for {word}, returning as is")
        return word

    def get_edits(self, word: str) -> Set[str]:
        """Get all strings that are one edit distance away from word."""
        letters = 'abcdefghijklmnopqrstuvwxyz'
        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        
        deletes = [L + R[1:] for L, R in splits if R]
        transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
        replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
        inserts = [L + c + R for L, R in splits for c in letters]
        
        return set(deletes + transposes + replaces + inserts)
    
    def evaluate_all_corpora(self, texts: Dict[str, str]) -> Dict[str, Tuple[float, List[Tuple[str, str, str]]]]:
        """Evaluate corrector on all corpora."""
        results = {}
        for corpus_name, text in texts.items():
            accuracy, errors = self.evaluate(text)
            results[corpus_name] = (accuracy, errors)
        return results

    def evaluate(self, text: str) -> Tuple[float, List[Tuple[str, str, str]]]:
        """Evaluate corrector on test corpus."""
        correct = 0
        total = 0
        errors = []
        
        if '<ERR' in text:  # Holbrook format
            err_pattern = re.compile(r'<ERR targ=([^>]+)>\s*([^<]+)\s*</ERR>')
            for match in err_pattern.finditer(text):
                correct_word = match.group(1).lower().replace('_', ' ')
                misspelling = match.group(2).lower().replace('_', ' ')
                if correct_word != '?':
                    prediction = self.correct(misspelling)
                    total += 1
                    if prediction == correct_word:
                        correct += 1
                    else:
                        errors.append((misspelling, correct_word, prediction))
        else:  # Birkbeck/Aspell/Wikipedia format
            current_word = None
            for line in text.split('\n'):
                line = line.strip()
                if not line:
                    continue
                if line.startswith('$'):
                    current_word = line[1:].lower().replace('_', ' ')
                elif current_word:
                    misspelling = line.lower().replace('_', ' ')
                    prediction = self.correct(misspelling)
                    total += 1
                    if prediction == current_word:
                        correct += 1
                    else:
                        errors.append((misspelling, current_word, prediction))
        
        return (correct / total if total > 0 else 0.0), errors

def load_and_train_corrector(corpus_texts: Dict[str, str]) -> EnhancedSpellingCorrector:
    corrector = EnhancedSpellingCorrector()
    
    # Train on each corpus
    for corpus_name, text in corpus_texts.items():
        print(f"\nTraining on {corpus_name}...")
        if corpus_name == 'holbrook-tagged':
            corrector.train_from_holbrook(text)
        else:  # birkbeck, aspell, wikipedia formats
            corrector.train_from_birkbeck(text)
    
    # Print statistics
    print("\nTraining Statistics:")
    print(f"Known words: {len(corrector.word_counts)}")
    print(f"Known misspellings: {len(corrector.misspelling_dict)}")
    print("\nSample of correct words:", list(corrector.word_counts.keys())[:5])
    print("Sample of misspellings:", list(corrector.misspelling_dict.items())[:5])
    
    return corrector

# Test with sample data
sample_corpus_texts = {
    'birkbeck': '''$receive
recieve
receve
receeve
$separate
seperate
seprate
$accommodate
accomodate
acomodate''',
    
    'holbrook-tagged': '''Here is some text with <ERR targ=receive>recieve</ERR> and 
<ERR targ=separate>seperate</ERR> as errors.''',
    
    'aspell': '''$receive
recieve
$separate
seperate''',
    
    'wikipedia': '''$receive
recieve
$separate
seperate'''
}

# Create and train the corrector
print("Training corrector...")
corrector = load_and_train_corrector(sample_corpus_texts)

# Test some corrections
print("\nTesting corrections:")
test_words = ["recieve", "seperate", "occured", "accomodate"]
for word in test_words:
    correction = corrector.correct(word)
    print(f"'{word}' -> '{correction}'")

# Evaluate on all corpora
print("\nEvaluating on all corpora:")
results = corrector.evaluate_all_corpora(sample_corpus_texts)
for corpus_name, (accuracy, errors) in results.items():
    print(f"\n{corpus_name} Results:")
    print(f"Accuracy: {accuracy:.2%}")
    if errors:
        print("Sample errors (misspelling -> correct -> predicted):")
        for error in errors[:3]:
            print(f"  {error[0]} -> {error[1]} -> {error[2]}")
# Out:
# Training corrector...
#
# Training on $Nevada...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_76318/3989393531.py in ?()
#     150 sample_corpus_texts = pd.read_csv('aspell.dat')
#     151
#     152 # Create and train the corrector
#     153 print("Training corrector...")
# --> 154 corrector = load_and_train_corrector(sample_corpus_texts)
#     155
#     156 # Test some corrections
#     157 print("\nTesting corrections:")
#
# /tmp/ipykernel_76318/3989393531.py in ?(corpus_texts)
#     134         print(f"\nTraining on {corpus_name}...")
#     135         if corpus_name == 'holbrook-tagged':
#     136             corrector.train_from_holbrook(text)
#     137         else:  # birkbeck, aspell, wikipedia formats
# --> 138             corrector.train_from_birkbeck(text)
#     139
#     140     # Print statistics
#     141     print("\nTraining Statistics:")
#
# /tmp/ipykernel_76318/3989393531.py in ?(self, text)
#      12     def train_from_birkbeck(self, text: str):
#      13         """Train from Birkbeck format ($correct\nmisspelling\nmisspelling...)"""
#      14         current_word = None
# ---> 15         for line in text.split('\n'):
#      16             line = line.strip()
#      17             if not line:
#      18                 continue
#
# ~/.local/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
from collections import Counter, defaultdict
import re
from typing import List, Set, Dict, Tuple

class SpellingCorrector:
    def __init__(self):
        self.word_counts = Counter()
        self.misspelling_dict = {}
        self.misspelling_sources = defaultdict(set)  # Track which files each misspelling came from
        
    def train_from_corpus(self, text: str, source_file: str):
        """Train from corpus format ($correct\nmisspelling\nmisspelling...)"""
        current_word = None
        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue
            if line.startswith('$'):
                current_word = line[1:].lower().replace('_', ' ')
                self.word_counts[current_word] += 1
            elif current_word:
                misspelling = line.lower().replace('_', ' ')
                # Add or update misspelling
                if misspelling in self.misspelling_dict:
                    if self.misspelling_dict[misspelling] != current_word:
                        print(f"Warning: Conflicting correction for '{misspelling}':")
                        print(f"  Previous: {self.misspelling_dict[misspelling]}")
                        print(f"  New: {current_word}")
                self.misspelling_dict[misspelling] = current_word
                self.misspelling_sources[misspelling].add(source_file)

    def get_edits(self, word: str) -> Set[str]:
        """Get all strings that are one edit distance away from word."""
        letters = 'abcdefghijklmnopqrstuvwxyz'
        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        
        deletes = [L + R[1:] for L, R in splits if R]
        transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
        replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
        inserts = [L + c + R for L, R in splits for c in letters]
        
        return set(deletes + transposes + replaces + inserts)

    def correct(self, word: str) -> str:
        """Return the most probable spelling correction for the word."""
        word = word.lower()
        
        # If word is known, return it
        if word in self.word_counts:
            return word
            
        # If word is a known misspelling, return correction
        if word in self.misspelling_dict:
            return self.misspelling_dict[word]
            
        # Get possible corrections (edit distance 1)
        candidates = self.get_edits(word)
        
        # Filter to known words and sort by frequency
        valid_candidates = [(w, self.word_counts[w]) for w in candidates if w in self.word_counts]
        
        if valid_candidates:
            return max(valid_candidates, key=lambda x: x[1])[0]
            
        # If no valid candidates found with edit distance 1,
        # try edit distance 2
        candidates2 = [e2 for e1 in candidates for e2 in self.get_edits(e1)]
        valid_candidates2 = [(w, self.word_counts[w]) for w in candidates2 if w in self.word_counts]
        
        if valid_candidates2:
            return max(valid_candidates2, key=lambda x: x[1])[0]
            
        return word

def load_and_analyze_corpus_files():
    corpus_files = [
        'birkbeck.dat',
        'holbrook-tagged.dat',
        'aspell.dat',
        'wikipedia.dat'
    ]
    
    corrector = SpellingCorrector()
    
    # Load and process each file
    for filename in corpus_files:
        try:
            with open(filename, 'r', encoding='utf-8') as f:
                print(f"\nLoading {filename}...")
                data = f.read()
                corrector.train_from_corpus(data, filename)
        except Exception as e:
            print(f"Error loading {filename}: {e}")
    
    # Analyze duplicates and sources
    print("\nAnalyzing corpus statistics...")
    
    # Count misspellings by number of sources
    source_counts = Counter(len(sources) for sources in corrector.misspelling_sources.values())
    
    print("\nMisspelling source statistics:")
    for num_sources, count in sorted(source_counts.items()):
        print(f"Misspellings found in {num_sources} file(s): {count}")
    
    # Find misspellings that appear in multiple files
    print("\nSample of misspellings found in multiple files:")
    multi_source_misspellings = [(misspelling, sources) 
                                for misspelling, sources in corrector.misspelling_sources.items() 
                                if len(sources) > 1]
    
    for misspelling, sources in sorted(multi_source_misspellings[:10]):
        correct = corrector.misspelling_dict[misspelling]
        print(f"'{misspelling}' -> '{correct}' (found in: {', '.join(sources)})")
    
    return corrector

# Create and train the corrector
print("Starting spelling corrector training...")
corrector = load_and_analyze_corpus_files()

# Print overall statistics
print(f"\nFinal Statistics:")
print(f"Total unique correct words: {len(corrector.word_counts)}")
print(f"Total unique misspellings: {len(corrector.misspelling_dict)}")

# Test some common misspellings
test_words = [
    "recieve", 
    "seperate", 
    "occured", 
    "accomodate",
    "neccessary",
    "wierd",
    "belive",
    "freind",
    "thier",
    "peice"
]

print("\nTesting corrections:")
for word in test_words:
    correction = corrector.correct(word)
    sources = corrector.misspelling_sources.get(word, set())
    if sources:
        print(f"'{word}' -> '{correction}' (found in: {', '.join(sources)})")
    else:
        print(f"'{word}' -> '{correction}' (not in training data)")

def interactive_testing():
    print("\nEnter words to correct (or 'quit' to exit):")
    while True:
        word = input("> ").strip().lower()
        if word == 'quit':
            break
        correction = corrector.correct(word)
        sources = corrector.misspelling_sources.get(word, set())
        if sources:
            print(f"'{word}' -> '{correction}' (found in: {', '.join(sources)})")
        else:
            print(f"'{word}' -> '{correction}' (not in training data)")

# Ask if user wants to try interactive testing
print("\nWould you like to try interactive testing? (yes/no)")
response = input().strip().lower()
if response.startswith('y'):
    interactive_testing()
# Out:
# Starting spelling corrector training...
# Error loading birkbeck.dat: [Errno 2] No such file or directory: 'birkbeck.dat'
# Error loading holbrook-tagged.dat: [Errno 2] No such file or directory: 'holbrook-tagged.dat'
#
# Loading aspell.dat...
# Warning: Conflicting correction for 'consident':
#   Previous: consistent
#   New: consonant
# Warning: Conflicting correction for 'faver':
#   Previous: favor
#   New: favour
# Warning: Conflicting correction for 'lilometer':
#   Previous: kilometer
#   New: kilometre
#
# Loading wikipedia.dat...
# Warning: Conflicting correction for 'cataline':
#   Previous: catalina
#   New: catiline
# Warning: Conflicting correction for 'liason':
#   Previous: liaison
#   New: mara liasson
# Warning: Conflicting correction for 'addres':
#   Previous: adders
#   New: address
# Warning: Conflicting correction for 'adviced':
#   Previous: advice
#   New: advised
# Warning: Conflicting correction for 'alot':
#   Previous: a lot
#   New: allot
# Warning: Conflicting correction for 'agina':
#   Previous: again
#   New: angina
# Warning: Conflicting correction for 'anual':
#   Previous: anal
#   New: annual
# Warning: Conflicting correction for 'appealling':
#   Previous: appalling
#   New: appealing
# Warning: Conflicting correction for 'archeaologist':
#   Previous: archaeologist
#   New: archeologist
# Warning: Conflicting correction for 'archeaologists':
#   Previous: archaeologists
#   New: archeologists
# Warning: Conflicting correction for 'archaoelogy':
#   Previous: archaeology
#   New: archeology
# Warning: Conflicting correction for 'archaology':
#   Previous: archaeology
#   New: archeology
# Warning: Conflicting correction for 'achive':
#   Previous: achieve
#   New: archive
# Warning: Conflicting correction for 'achived':
#   Previous: achieved
#   New: archived
# Warning: Conflicting correction for 'amature':
#   Previous: amateur
#   New: armature
# Warning: Conflicting correction for 'accension':
#   Previous: accession
#   New: ascension
# Warning: Conflicting correction for 'attaindre':
#   Previous: attainder
#   New: attained
# Warning: Conflicting correction for 'ackward':
#   Previous: awkward
#   New: backward
# Warning: Conflicting correction for 'beggin':
#   Previous: begging
#   New: begin
# Warning: Conflicting correction for 'behavour':
#   Previous: behavior
#   New: behaviour
# Warning: Conflicting correction for 'belives':
#   Previous: beliefs
#   New: believes
# Warning: Conflicting correction for 'boaut':
#   Previous: about
#   New: boat
# Warning: Conflicting correction for 'baout':
#   Previous: about
#   New: bout
# Warning: Conflicting correction for 'boaut':
#   Previous: boat
#   New: bout
# Warning: Conflicting correction for 'buring':
#   Previous: burin
#   New: burning
# Warning: Conflicting correction for 'buring':
#   Previous: burning
#   New: burying
# Warning: Conflicting correction for 'busineses':
#   Previous: business
#   New: businesses
# Warning: Conflicting correction for 'cant':
#   Previous: can't
#   New: cant
# Warning: Conflicting correction for 'carcas':
#   Previous: caracas
#   New: carcass
# Warning: Conflicting correction for 'censur':
#   Previous: censor
#   New: censure
# Warning: Conflicting correction for 'chasr':
#   Previous: chase
#   New: chaser
# Warning: Conflicting correction for 'comander':
#   Previous: commandeer
#   New: commander
# Warning: Conflicting correction for 'competion':
#   Previous: competition
#   New: completion
# Warning: Conflicting correction for 'contemporaneus':
#   Previous: contemporaneous
#   New: contemporary
# Warning: Conflicting correction for 'coorperation':
#   Previous: cooperation
#   New: corporation
# Warning: Conflicting correction for 'coudl':
#   Previous: cloud
#   New: could
# Warning: Conflicting correction for 'councellor':
#   Previous: councillor
#   New: counsellor
# Warning: Conflicting correction for 'councellors':
#   Previous: councillors
#   New: counsellors
# Warning: Conflicting correction for 'councellor':
#   Previous: counsellor
#   New: counselor
# Warning: Conflicting correction for 'councellors':
#   Previous: counsellors
#   New: counselors
# Warning: Conflicting correction for 'coururier':
#   Previous: courier
#   New: couturier
# Warning: Conflicting correction for 'coverted':
#   Previous: converted
#   New: covered
# Warning: Conflicting correction for 'coverted':
#   Previous: covered
#   New: coveted
# Warning: Conflicting correction for 'cpoy':
#   Previous: copy
#   New: coy
# Warning: Conflicting correction for 'critisize':
#   Previous: criticise
#   New: criticize
# Warning: Conflicting correction for 'critisized':
#   Previous: criticised
#   New: criticized
# Warning: Conflicting correction for 'critisizes':
#   Previous: criticises
#   New: criticizes
# Warning: Conflicting correction for 'critising':
#   Previous: criticising
#   New: criticizing
# Warning: Conflicting correction for 'critisizing':
#   Previous: criticising
#   New: criticizing
# Warning: Conflicting correction for 'dael':
#   Previous: dahl
#   New: deal
# Warning: Conflicting correction for 'damenor':
#   Previous: demeanor
#   New: demeanour
# Warning: Conflicting correction for 'demenor':
#   Previous: demeanor
#   New: demeanour
# Warning: Conflicting correction for 'dael':
#   Previous: deal
#   New: dial
# Warning: Conflicting correction for 'desparate':
#   Previous: desperate
#   New: disparate
# Warning: Conflicting correction for 'diversed':
#   Previous: diverged
#   New: diverse
# Warning: Conflicting correction for 'doub':
#   Previous: daub
#   New: doubt
# Warning: Conflicting correction for 'deram':
#   Previous: dram
#   New: dream
# Warning: Conflicting correction for 'adressing':
#   Previous: addressing
#   New: dressing
# Warning: Conflicting correction for 'buring':
#   Previous: burying
#   New: during
# Warning: Conflicting correction for 'dieing':
#   Previous: dyeing
#   New: dying
# Warning: Conflicting correction for 'affort':
#   Previous: afford
#   New: effort
# Warning: Conflicting correction for 'efford':
#   Previous: afford
#   New: effort
# Warning: Conflicting correction for 'effords':
#   Previous: affords
#   New: efforts
# Warning: Conflicting correction for 'electic':
#   Previous: eclectic
#   New: electric
# Warning: Conflicting correction for 'electon':
#   Previous: election
#   New: electron
# Warning: Conflicting correction for 'emition':
#   Previous: emission
#   New: emotion
# Warning: Conflicting correction for 'enlish':
#   Previous: english
#   New: enlist
# Warning: Conflicting correction for 'erested':
#   Previous: arrested
#   New: erected
# Warning: Conflicting correction for 'spects':
#   Previous: aspects
#   New: expects
# Warning: Conflicting correction for 'extint':
#   Previous: extant
#   New: extinct
# Warning: Conflicting correction for 'fiel':
#   Previous: feel
#   New: field
# Warning: Conflicting correction for 'fiels':
#   Previous: feels
#   New: fields
# Warning: Conflicting correction for 'fiel':
#   Previous: field
#   New: file
# Warning: Conflicting correction for 'fiels':
#   Previous: fields
#   New: files
# Warning: Conflicting correction for 'firts':
#   Previous: first
#   New: flirts
# Warning: Conflicting correction for 'fleed':
#   Previous: fled
#   New: freed
# Warning: Conflicting correction for 'fomr':
#   Previous: form
#   New: from
# Warning: Conflicting correction for 'gae':
#   Previous: gael
#   New: gale
# Warning: Conflicting correction for 'gae':
#   Previous: gale
#   New: game
# Warning: Conflicting correction for 'gogin':
#   Previous: gauguin
#   New: going
# Warning: Conflicting correction for 'gaurd':
#   Previous: guard
#   New: gourd
# Warning: Conflicting correction for 'gaurd':
#   Previous: gourd
#   New: guard
# Warning: Conflicting correction for 'guerrila':
#   Previous: guerilla
#   New: guerrilla
# Warning: Conflicting correction for 'guerrilas':
#   Previous: guerillas
#   New: guerrillas
# Warning: Conflicting correction for 'haev':
#   Previous: have
#   New: heave
# Warning: Conflicting correction for 'hvea':
#   Previous: have
#   New: heave
# Warning: Conflicting correction for 'diea':
#   Previous: die
#   New: idea
# Warning: Conflicting correction for 'idesa':
#   Previous: ideas
#   New: ides
# Warning: Conflicting correction for 'alusion':
#   Previous: allusion
#   New: illusion
# Warning: Conflicting correction for 'imaginery':
#   Previous: imagery
#   New: imaginary
# Warning: Conflicting correction for 'iminent':
#   Previous: eminent
#   New: immanent
# Warning: Conflicting correction for 'imigrant':
#   Previous: emigrant
#   New: immigrant
# Warning: Conflicting correction for 'imigrated':
#   Previous: emigrated
#   New: immigrated
# Warning: Conflicting correction for 'imigration':
#   Previous: emigration
#   New: immigration
# Warning: Conflicting correction for 'emminent':
#   Previous: eminent
#   New: imminent
# Warning: Conflicting correction for 'imanent':
#   Previous: eminent
#   New: imminent
# Warning: Conflicting correction for 'iminent':
#   Previous: immanent
#   New: imminent
# Warning: Conflicting correction for 'empirial':
#   Previous: empirical
#   New: imperial
# Warning: Conflicting correction for 'inheritage':
#   Previous: heritage
#   New: inheritance
# Warning: Conflicting correction for 'inumerable':
#   Previous: enumerable
#   New: innumerable
# Warning: Conflicting correction for 'ecidious':
#   Previous: deciduous
#   New: insidious
# Warning: Conflicting correction for 'interbread':
#   Previous: interbred
#   New: interbreed
# Warning: Conflicting correction for 'ceratin':
#   Previous: certain
#   New: keratin
# Warning: Conflicting correction for 'leanr':
#   Previous: lean
#   New: leaner
# Warning: Conflicting correction for 'leanr':
#   Previous: leaner
#   New: learn
# Warning: Conflicting correction for 'liason':
#   Previous: mara liasson
#   New: liaison
# Warning: Conflicting correction for 'lible':
#   Previous: liable
#   New: libel
# Warning: Conflicting correction for 'lisence':
#   Previous: licence
#   New: license
# Warning: Conflicting correction for 'lisense':
#   Previous: licence
#   New: license
# Warning: Conflicting correction for 'lief':
#   Previous: leaf
#   New: life
# Warning: Conflicting correction for 'alot':
#   Previous: allot
#   New: lot
# Warning: Conflicting correction for 'manoeuverability':
#   Previous: maneuverability
#   New: manoeuvrability
# Warning: Conflicting correction for 'manouverability':
#   Previous: maneuverability
#   New: manoeuvrability
# Warning: Conflicting correction for 'manouverable':
#   Previous: maneuverable
#   New: manoeuvrable
# Warning: Conflicting correction for 'manouver':
#   Previous: maneuver
#   New: manoeuvre
# Warning: Conflicting correction for 'manuever':
#   Previous: maneuver
#   New: manoeuvre
# Warning: Conflicting correction for 'manouvers':
#   Previous: maneuvers
#   New: manoeuvres
# Warning: Conflicting correction for 'manuevers':
#   Previous: maneuvers
#   New: manoeuvres
# Warning: Conflicting correction for 'maked':
#   Previous: made
#   New: marked
# Warning: Conflicting correction for 'medeival':
#   Previous: mediaeval
#   New: medieval
# Warning: Conflicting correction for 'mear':
#   Previous: mare
#   New: mere
# Warning: Conflicting correction for 'misdameanor':
#   Previous: misdemeanor
#   New: misdemeanour
# Warning: Conflicting correction for 'misdemenor':
#   Previous: misdemeanor
#   New: misdemeanour
# Warning: Conflicting correction for 'misdameanors':
#   Previous: misdemeanors
#   New: misdemeanours
# Warning: Conflicting correction for 'misdemenors':
#   Previous: misdemeanors
#   New: misdemeanours
# Warning: Conflicting correction for 'missle':
#   Previous: missel
#   New: missile
# Warning: Conflicting correction for 'monestary':
#   Previous: monastery
#   New: monetary
# Warning: Conflicting correction for 'famoust':
#   Previous: famous
#   New: most famous
# Warning: Conflicting correction for 'muscels':
#   Previous: muscles
#   New: mussels
# Warning: Conflicting correction for 'neigbour':
#   Previous: neighbor
#   New: neighbour
# Warning: Conflicting correction for 'neigbouring':
#   Previous: neighboring
#   New: neighbouring
# Warning: Conflicting correction for 'neigbours':
#   Previous: neighbors
#   New: neighbours
# Warning: Conflicting correction for 'neice':
#   Previous: niece
#   New: nice
# Warning: Conflicting correction for 'neice':
#   Previous: nice
#   New: niece
# Warning: Conflicting correction for 'onot':
#   Previous: not
#   New: note
# Warning: Conflicting correction for 'oging':
#   Previous: going
#   New: ogling
# Warning: Conflicting correction for 'noone':
#   Previous: no one
#   New: one
# Warning: Conflicting correction for 'lonly':
#   Previous: lonely
#   New: only
# Warning: Conflicting correction for 'orgin':
#   Previous: organ
#   New: origin
# Warning: Conflicting correction for 'orginal':
#   Previous: orignal
#   New: original
# Warning: Conflicting correction for 'penninsular':
#   Previous: peninsula
#   New: peninsular
# Warning: Conflicting correction for 'performes':
#   Previous: performed
#   New: performs
# Warning: Conflicting correction for 'personel':
#   Previous: personal
#   New: personnel
# Warning: Conflicting correction for 'phenomenonly':
#   Previous: phenomenal
#   New: phenomenally
# Warning: Conflicting correction for 'fiel':
#   Previous: file
#   New: phial
# Warning: Conflicting correction for 'fiels':
#   Previous: files
#   New: phials
# Warning: Conflicting correction for 'palce':
#   Previous: palace
#   New: place
# Warning: Conflicting correction for 'positon':
#   Previous: position
#   New: positron
# Warning: Conflicting correction for 'profesion':
#   Previous: profession
#   New: profusion
# Warning: Conflicting correction for 'progrom':
#   Previous: pogrom
#   New: program
# Warning: Conflicting correction for 'progroms':
#   Previous: pogroms
#   New: programs
# Warning: Conflicting correction for 'prominately':
#   Previous: predominately
#   New: prominently
# Warning: Conflicting correction for 'protem':
#   Previous: pro tem
#   New: protein
# Warning: Conflicting correction for 'perphas':
#   Previous: perhaps
#   New: purpose
# Warning: Conflicting correction for 'qtuie':
#   Previous: quiet
#   New: quite
# Warning: Conflicting correction for 'qutie':
#   Previous: quiet
#   New: quite
# Warning: Conflicting correction for 'relized':
#   Previous: realised
#   New: realized
# Warning: Conflicting correction for 'erally':
#   Previous: orally
#   New: really
# Warning: Conflicting correction for 'repatition':
#   Previous: repartition
#   New: repetition
# Warning: Conflicting correction for 'restraunt':
#   Previous: restaurant
#   New: restraint
# Warning: Conflicting correction for 'rigeur':
#   Previous: rigor
#   New: rigour
# Warning: Conflicting correction for 'roomate':
#   Previous: room-mate
#   New: roommate
# Warning: Conflicting correction for 'sasy':
#   Previous: sassy
#   New: says
# Warning: Conflicting correction for 'scholarstic':
#   Previous: scholarly
#   New: scholastic
# Warning: Conflicting correction for 'clera':
#   Previous: clear
#   New: sclera
# Warning: Conflicting correction for 'sepulchure':
#   Previous: sepulcher
#   New: sepulchre
# Warning: Conflicting correction for 'sepulcre':
#   Previous: sepulcher
#   New: sepulchre
# Warning: Conflicting correction for 'cervial':
#   Previous: cervical
#   New: serval
# Warning: Conflicting correction for 'cervial':
#   Previous: serval
#   New: servile
# Warning: Conflicting correction for 'sheat':
#   Previous: cheat
#   New: sheath
# Warning: Conflicting correction for 'sheat':
#   Previous: sheath
#   New: sheet
# Warning: Conflicting correction for 'sould':
#   Previous: could
#   New: should
# Warning: Conflicting correction for 'shoudln':
#   Previous: should
#   New: shouldn't
# Warning: Conflicting correction for 'sinse':
#   Previous: since
#   New: sines
# Warning: Conflicting correction for 'sieze':
#   Previous: seize
#   New: size
# Warning: Conflicting correction for 'siezed':
#   Previous: seized
#   New: sized
# Warning: Conflicting correction for 'siezing':
#   Previous: seizing
#   New: sizing
# Warning: Conflicting correction for 'sould':
#   Previous: should
#   New: sold
# Warning: Conflicting correction for 'speciallized':
#   Previous: specialised
#   New: specialized
# Warning: Conflicting correction for 'specif':
#   Previous: specific
#   New: specify
# Warning: Conflicting correction for 'spermatozoan':
#   Previous: spermatozoa
#   New: spermatozoon
# Warning: Conflicting correction for 'sotyr':
#   Previous: satyr
#   New: story
# Warning: Conflicting correction for 'stroy':
#   Previous: destroy
#   New: story
# Warning: Conflicting correction for 'strat':
#   Previous: start
#   New: strata
# Warning: Conflicting correction for 'strived':
#   Previous: striven
#   New: strove
# Warning: Conflicting correction for 'seceed':
#   Previous: secede
#   New: succeed
# Warning: Conflicting correction for 'secceeded':
#   Previous: seceded
#   New: succeeded
# Warning: Conflicting correction for 'seceeded':
#   Previous: seceded
#   New: succeeded
# Warning: Conflicting correction for 'surley':
#   Previous: surely
#   New: surly
# Warning: Conflicting correction for 'surrended':
#   Previous: surrendered
#   New: surrounded
# Warning: Conflicting correction for 'theather':
#   Previous: theater
#   New: theatre
# Warning: Conflicting correction for 'ther':
#   Previous: the
#   New: their
# Warning: Conflicting correction for 'ther':
#   Previous: their
#   New: there
# Warning: Conflicting correction for 'thikning':
#   Previous: thickening
#   New: thinking
# Warning: Conflicting correction for 'ethose':
#   Previous: ethos
#   New: those
# Warning: Conflicting correction for 'throught':
#   Previous: through
#   New: throughout
# Warning: Conflicting correction for 'tiem':
#   Previous: tim
#   New: time
# Warning: Conflicting correction for 'tiome':
#   Previous: time
#   New: tome
# Warning: Conflicting correction for 'tourch':
#   Previous: torch
#   New: touch
# Warning: Conflicting correction for 'transcripting':
#   Previous: transcribing
#   New: transcription
# Warning: Conflicting correction for 'troups':
#   Previous: troops
#   New: troupes
# Warning: Conflicting correction for 'turnk':
#   Previous: trunk
#   New: turnkey
# Warning: Conflicting correction for 'unsed':
#   Previous: unsaid
#   New: unused
# Warning: Conflicting correction for 'apon':
#   Previous: apron
#   New: upon
# Warning: Conflicting correction for 'useage':
#   Previous: usage
#   New: use
# Warning: Conflicting correction for 'unsed':
#   Previous: unused
#   New: used
# Warning: Conflicting correction for 'agina':
#   Previous: angina
#   New: vagina
# Warning: Conflicting correction for 'meranda':
#   Previous: miranda
#   New: veranda
# Warning: Conflicting correction for 'vigeur':
#   Previous: vigor
#   New: vigour
# Warning: Conflicting correction for 'villin':
#   Previous: villain
#   New: villein
# Warning: Conflicting correction for 'villin':
#   Previous: villein
#   New: villi
# Warning: Conflicting correction for 'mear':
#   Previous: mere
#   New: wear
# Warning: Conflicting correction for 'wether':
#   Previous: weather
#   New: whether
# Warning: Conflicting correction for 'wholy':
#   Previous: holy
#   New: wholly
# Warning: Conflicting correction for 'weild':
#   Previous: wield
#   New: wild
# Warning: Conflicting correction for 'wich':
#   Previous: which
#   New: witch
# Warning: Conflicting correction for 'withdrawl':
#   Previous: withdraw
#   New: withdrawal
# Warning: Conflicting correction for 'wont':
#   Previous: won't
#   New: wont
# Warning: Conflicting correction for 'eyars':
#   Previous: eyas
#   New: years
#
# Analyzing corpus statistics...
#
# Misspelling source statistics:
# Misspellings found in 1 file(s): 2639
# Misspellings found in 2 file(s): 64
#
# Sample of misspellings found in multiple files:
# 'absorbtion' -> 'absorption' (found in: wikipedia.dat, aspell.dat)
# 'accidently' -> 'accidentally' (found in: wikipedia.dat, aspell.dat)
# 'accomodate' -> 'accommodate' (found in: wikipedia.dat, aspell.dat)
# 'alchohol' -> 'alcohol' (found in: wikipedia.dat, aspell.dat)
# 'amature' -> 'armature' (found in: wikipedia.dat, aspell.dat)
# 'annoint' -> 'anoint' (found in: wikipedia.dat, aspell.dat)
# 'basicly' -> 'basically' (found in: wikipedia.dat, aspell.dat)
# 'beaurocracy' -> 'bureaucracy' (found in: wikipedia.dat, aspell.dat)
# 'beggining' -> 'beginning' (found in: wikipedia.dat, aspell.dat)
# 'beleive' -> 'believe' (found in: wikipedia.dat, aspell.dat)
#
# Final Statistics:
# Total unique correct words: 2238
# Total unique misspellings: 2703
#
# Testing corrections:
# 'recieve' -> 'receive' (found in: wikipedia.dat, aspell.dat)
# 'seperate' -> 'separate' (found in: wikipedia.dat, aspell.dat)
# 'occured' -> 'occurred' (found in: wikipedia.dat)
# 'accomodate' -> 'accommodate' (found in: wikipedia.dat, aspell.dat)
# 'neccessary' -> 'necessary' (found in: wikipedia.dat, aspell.dat)
# 'wierd' -> 'weird' (found in: wikipedia.dat, aspell.dat)
# 'belive' -> 'believe' (found in: aspell.dat)
# 'freind' -> 'friend' (found in: wikipedia.dat)
# 'thier' -> 'their' (found in: wikipedia.dat)
# 'peice' -> 'piece' (found in: wikipedia.dat)
#
# Would you like to try interactive testing? (yes/no)

# %%
from collections import Counter
import re
import random
from typing import List, Set, Dict, Tuple

class EnhancedSpellingCorrector:
    def __init__(self):
        self.word_counts = Counter()
        self.misspelling_dict = {}
        self.debug_mode = True 
        
    def train_from_birkbeck(self, text: str, test_ratio=0.2):
        current_word = None
        test_data = []
        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue
            if line.startswith('$'):
                current_word = line[1:].lower().replace('_', ' ')
                self.word_counts[current_word] += 1
            elif current_word:
                misspelling = line.lower().replace('_', ' ')
                if random.random() < test_ratio:
                    test_data.append((misspelling, current_word))
                else:
                    self.misspelling_dict[misspelling] = current_word
        return test_data
    
    def train_from_holbrook(self, text: str, test_ratio=0.2):
        err_pattern = re.compile(r'<ERR targ=([^>]+)>\s*([^<]+)\s*</ERR>')
        test_data = []
        for match in err_pattern.finditer(text):
            correct = match.group(1).lower().replace('_', ' ')
            misspelling = match.group(2).lower().replace('_', ' ')
            if correct != '?':
                self.word_counts[correct] += 1
                if random.random() < test_ratio:
                    test_data.append((misspelling, correct))
                else:
                    self.misspelling_dict[misspelling] = correct
        return test_data
    
    def correct(self, word: str) -> str:
        word = word.lower()
        if word in self.word_counts:
            return word
        if word in self.misspelling_dict:
            return self.misspelling_dict[word]
        candidates = self.get_edits(word)
        valid_candidates = [(w, self.word_counts[w]) for w in candidates if w in self.word_counts]
        return max(valid_candidates, key=lambda x: x[1])[0] if valid_candidates else word

    def get_edits(self, word: str) -> Set[str]:
        letters = 'abcdefghijklmnopqrstuvwxyz'
        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes = [L + R[1:] for L, R in splits if R]
        transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
        replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
        inserts = [L + c + R for L, R in splits for c in letters]
        return set(deletes + transposes + replaces + inserts)
    
    def train_from_files(self, file_paths: List[str]):
        all_text = ""
        test_data = []
        for file_path in file_paths:
            with open(file_path, 'r', encoding='utf-8') as file:
                all_text += file.read() + "\n"
        
        if 'ERR' in all_text:
            test_data = self.train_from_holbrook(all_text)
        else:
            test_data = self.train_from_birkbeck(all_text)
        
        return test_data
    
    def evaluate(self, test_data: List[Tuple[str, str]]):
        correct_predictions = 0
        total = len(test_data)
        for misspelled, correct in test_data:
            prediction = self.correct(misspelled)
            if prediction == correct:
                correct_predictions += 1
        accuracy = correct_predictions / total if total > 0 else 0
        print(f"Accuracy: {accuracy:.2%}")

def load_and_train_corrector(file_paths: List[str]) -> EnhancedSpellingCorrector:
    corrector = EnhancedSpellingCorrector()
    test_data = corrector.train_from_files(file_paths)
    print("Training complete.")
    corrector.evaluate(test_data)
    return corrector

# Specify dataset files
file_paths = ["/workspaces/Spelling-Corrector/aspell.dat", "/workspaces/Spelling-Corrector/holbrook-missp.dat", "/workspaces/Spelling-Corrector/missp.dat", "/workspaces/Spelling-Corrector/wikipedia.dat"]
corrector = load_and_train_corrector(file_paths)

# Test corrections
test_words = ["recieve", "goood", "occured", "accomodate"]
for word in test_words:
    print(f"'{word}' -> '{corrector.correct(word)}'")
# Out:
# Training complete.
# Accuracy: 26.60%
# 'recieve' -> 'receive'
# 'goood' -> 'good'
# 'occured' -> 'occurred'
# 'accomodate' -> 'accommodate'

# %%
import re
import random
from collections import Counter, defaultdict
from typing import List, Set, Dict, Tuple
from sklearn.mixture import GaussianMixture
import numpy as np


class EnhancedSpellingCorrector:
    def __init__(self):
        self.word_counts = Counter()
        self.misspelling_dict = {}
        self.ngram_counts = defaultdict(Counter)
        self.debug_mode = True
        self.gmm = None
        
    def train_from_birkbeck(self, text: str, test_ratio=0.2):
        current_word = None
        test_data = []
        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue
            if line.startswith('$'):
                current_word = line[1:].lower().replace('_', ' ')
                self.word_counts[current_word] += 1
            elif current_word:
                misspelling = line.lower().replace('_', ' ')
                if random.random() < test_ratio:
                    test_data.append((misspelling, current_word))
                else:
                    self.misspelling_dict[misspelling] = current_word
                    self.update_ngram(misspelling, current_word)
        return test_data
    
    def train_from_holbrook(self, text: str, test_ratio=0.2):
        err_pattern = re.compile(r'<ERR targ=([^>]+)>\s*([^<]+)\s*</ERR>')
        test_data = []
        for match in err_pattern.finditer(text):
            correct = match.group(1).lower().replace('_', ' ')
            misspelling = match.group(2).lower().replace('_', ' ')
            if correct != '?':
                self.word_counts[correct] += 1
                if random.random() < test_ratio:
                    test_data.append((misspelling, correct))
                else:
                    self.misspelling_dict[misspelling] = correct
                    self.update_ngram(misspelling, correct)
        return test_data

    def update_ngram(self, misspelled: str, correct: str):
        """Generates unigrams and bigrams from misspelled and correct words"""
        # Add unigrams
        self.ngram_counts['unigrams'][misspelled] += 1
        self.ngram_counts['unigrams'][correct] += 1
        # Add bigrams
        misspelled_bigram = tuple(misspelled[i:i+2] for i in range(len(misspelled)-1))
        correct_bigram = tuple(correct[i:i+2] for i in range(len(correct)-1))
        self.ngram_counts['bigrams'][misspelled_bigram] += 1
        self.ngram_counts['bigrams'][correct_bigram] += 1

    def correct(self, word: str) -> str:
        word = word.lower()
        if word in self.word_counts:
            return word
        if word in self.misspelling_dict:
            return self.misspelling_dict[word]

        # Apply N-gram model for context-based correction
        candidates = self.get_edits(word)
        valid_candidates = [(w, self.word_counts[w]) for w in candidates if w in self.word_counts]

        if valid_candidates:
            # N-gram-based correction
            best_word = max(valid_candidates, key=lambda x: x[1])[0]
            return best_word
        
        # Apply GMM for probabilistic correction
        return self.gmm_correction(word) or word

    def get_edits(self, word: str) -> Set[str]:
        letters = 'abcdefghijklmnopqrstuvwxyz'
        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes = [L + R[1:] for L, R in splits if R]
        transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
        replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
        inserts = [L + c + R for L, R in splits for c in letters]
        return set(deletes + transposes + replaces + inserts)

    def train_gmm(self):
        """Train a Gaussian Mixture Model for word correction"""
        all_words = list(self.word_counts.keys())
        word_vectors = np.vstack([self.vectorize_word(w) for w in all_words])
        self.gmm = GaussianMixture(n_components=2).fit(word_vectors)

    def vectorize_word(self, word: str, max_length=10) -> np.ndarray:
        """Convert word to a fixed-length numeric vector representation"""
        vec = [ord(c) for c in word[:max_length]]  # Truncate if longer
        vec += [0] * (max_length - len(vec))  # Pad if shorter
        return np.array(vec, dtype=np.float32)


    def gmm_correction(self, word: str) -> str:
        """Use GMM to find the best correction"""
        if not self.gmm:
            return None
        word_vector = self.vectorize_word(word).reshape(1, -1)
        probabilities = self.gmm.predict_proba(word_vector)
        best_component = np.argmax(probabilities)
        word_candidates = list(self.word_counts.keys())
        # Return the most probable word for the best component
        return word_candidates[best_component] if probabilities[0, best_component] > 0.5 else None

    def train_from_files(self, file_paths: List[str]):
        all_text = ""
        test_data = []
        for file_path in file_paths:
            with open(file_path, 'r', encoding='utf-8') as file:
                all_text += file.read() + "\n"

        if 'ERR' in all_text:
            test_data = self.train_from_holbrook(all_text)
        else:
            test_data = self.train_from_birkbeck(all_text)

        self.train_gmm()
        return test_data

    def evaluate(self, test_data: List[Tuple[str, str]]):
        correct_predictions = 0
        total = len(test_data)
        for misspelled, correct in test_data:
            prediction = self.correct(misspelled)
            if prediction == correct:
                correct_predictions += 1
        accuracy = correct_predictions / total if total > 0 else 0
        print(f"Accuracy: {accuracy:.2%}")


def load_and_train_corrector(file_paths: List[str]) -> EnhancedSpellingCorrector:
    corrector = EnhancedSpellingCorrector()
    test_data = corrector.train_from_files(file_paths)
    print("Training complete.")
    corrector.evaluate(test_data)
    return corrector


# Specify dataset files
file_paths = ["/workspaces/Spelling-Corrector/aspell.dat", "/workspaces/Spelling-Corrector/holbrook-missp.dat", "/workspaces/Spelling-Corrector/missp.dat", "/workspaces/Spelling-Corrector/wikipedia.dat"]
corrector = load_and_train_corrector(file_paths)

# Test corrections
test_words = ["recieve", "goood", "occured", "accomodate"]
for word in test_words:
    print(f"'{word}' -> '{corrector.correct(word)}'")
# Out:
# Training complete.
# Accuracy: 26.66%
# 'recieve' -> 'receive'
# 'goood' -> 'good'
# 'occured' -> 'occurred'
# 'accomodate' -> 'accommodate'
